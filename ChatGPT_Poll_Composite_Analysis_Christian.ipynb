# %% [markdown]
# # ChatGPT Poll Composite Variable Analysis - Feature Seperation
# Modified By: Christian Sarmiento <br>
# <br>
# Changes:
# - Reran ANOVA tests with students and instructors seperated (using EL-recoded dataset and analysis code)

# %%
# Imports 
import pandas as pd 
import numpy as np 
import statsmodels.api as sm 
from statsmodels.stats.multicomp import MultiComparison
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in data 
path = '/Users/christiansarmiento/Library/CloudStorage/OneDrive-MaristCollege/Center for Social Media Research/ChatGPT Research/pollcodeddata.csv'
data = pd.read_csv(path)

# %%
# Double checking 
data.head(20)
# Out:
#     Q2_AWARENESS                Q4_SOURCE  Q5_REASON_STUDENT  Q6_REASON_PROF  \
# 0              1            From the news                  1               2
# 1              2            From the news                  3               2
# 2              2            From a friend                  3               3
# 3              1     From a family member                  2               2
# 4              4            From a friend                  4               1
# 5              2            From the news                  1               2
# 6              1            From the news                  1               3
# 7              1     From a family member                  2               3
# 8              4                     None                  4               1
# 9              4  From this questionnaire                  4               4
# 10             4                     None                  3               4
# 11             2            From the news                  1               3
# 12             4  From this questionnaire                  3               2
# 13             4  From this questionnaire                  4               4
# 14             1            From the news                  3               3
# 15             4  From this questionnaire                  4               4
# 16             2            From the news                  2               3
# 17             1            From the news                  2               4
# 18             2            From the news                  2               3
# 19             2            From the news                  1               2
#
#     Q71_BENEFITS  Q72_LIMITATIONS  Q73_IMPLICATIONS  Q81_LIKELY_PRODUCTIVE  \
# 0              4                4                 4                      3
# 1              1                1                 1                      1
# 2              1                2                 2                      1
# 3              1                1                 1                      2
# 4              1                2                 2                      1
# 5              1                2                 1                      1
# 6              2                2                 2                      2
# 7              1                4                 2                      2
# 8              2                1                 3                      1
# 9              1                3                 3                      1
# 10             2                3                 3                      1
# 11             2                1                 1                      2
# 12             2                2                 2                      2
# 13             2                2                 1                      2
# 14             1                1                 1                      1
# 15             3                3                 3                      3
# 16             2                2                 1                      3
# 17             2                2                 1                      4
# 18             2                1                 1                      1
# 19             2                2                 1                      2
#
#     Q82_PRODUCTIVE_STUDENT  Q83_PRODUCTIVE_PROF  ...  LIMITATIONS  \
# 0                        3                    3  ...     2.171730
# 1                        2                    1  ...    -1.022405
# 2                        2                    2  ...     0.042306
# 3                        2                    2  ...    -1.022405
# 4                        3                    1  ...     0.042306
# 5                        2                    1  ...     0.042306
# 6                        4                    2  ...     0.042306
# 7                        2                    2  ...     2.171730
# 8                        2                    1  ...    -1.022405
# 9                        1                    1  ...     1.107018
# 10                       2                    1  ...     1.107018
# 11                       3                    2  ...    -1.022405
# 12                       4                    2  ...     0.042306
# 13                       5                    2  ...     0.042306
# 14                       4                    2  ...    -1.022405
# 15                       3                    3  ...     1.107018
# 16                       2                    2  ...     0.042306
# 17                       4                    4  ...     0.042306
# 18                       2                    2  ...    -1.022405
# 19                       4                    2  ...     0.042306
#
#     IMPLICATIONS  WORK_PRODUCTIVITY  PLAGIARISM  SOCIAL_IMPACT  \
# 0       2.373974           0.705744   -1.463215       0.969679
# 1      -0.821896          -0.721571   -0.073755      -0.907521
# 2       0.243394          -0.587772   -0.628901       0.969679
# 3      -0.821896          -0.297750   -0.407348       0.969679
# 4       0.243394          -0.141898    0.798437      -0.907521
# 5      -0.821896          -0.896927    0.445107      -0.907521
# 6       0.243394           0.686241   -0.630496      -0.907521
# 7       0.243394          -0.122395    0.742417       0.969679
# 8       1.308684          -0.896927   -0.091897      -0.907521
# 9       1.308684          -1.301245    0.205413      -0.907521
# 10      1.308684          -0.721571    0.482985      -0.907521
# 11     -0.821896           0.106568   -0.926211       0.969679
# 12      0.243394           0.160174   -0.371065       0.969679
# 13     -0.821896           0.389136    0.704538       0.969679
# 14     -0.821896          -0.129848    0.704538       0.969679
# 15      1.308684           0.705744    0.205413       2.846879
# 16     -0.821896          -0.007728   -0.944353       0.969679
# 17     -0.821896           1.358528    0.463249       0.969679
# 18     -0.821896          -0.412417    1.039726      -0.907521
# 19     -0.821896           0.160174   -0.926211      -0.907521
#
#     HIGHERED_BENEFIT     USAGE  RESP_USE_TRUST_BENEF  ACCURACY     TRUST
# 0           1.707759  0.895819              1.543423  0.254953  1.750332
# 1          -1.149544 -0.751619             -0.549300 -0.296804 -0.685842
# 2          -1.149544 -0.676335             -0.765636 -1.025810 -0.685842
# 3           0.279107 -1.315724             -0.708271 -0.109550 -0.685842
# 4          -1.149544  0.895819             -0.631084  0.067700 -1.123160
# 5           0.279107 -1.018573             -0.952564  0.432203 -0.311102
# 6          -1.149544  0.895819              0.764724 -0.296804 -0.248524
# 7           0.279107 -0.394283             -0.061340 -1.025810 -0.685842
# 8          -1.149544  0.895819             -0.212884 -1.025810 -1.060582
# 9          -1.149544  0.895819             -0.777972  0.806710 -1.497900
# 10         -1.149544  0.895819             -0.557209 -1.025810 -0.685842
# 11         -1.149544  0.895819             -0.097243 -0.661307 -0.685842
# 12          0.279107  0.895819              0.232283 -0.474054 -0.311102
# 13          1.707759  0.895819              1.028518 -1.025810 -0.685842
# 14         -1.149544 -1.033672             -0.722556  0.254953  0.063638
# 15          1.707759  0.895819              0.232283  0.806710  0.126216
# 16          0.279107  0.895819              0.175737  0.806710 -0.311102
# 17         -1.149544  0.895819             -0.195934  0.432203  0.875696
# 18          0.279107  0.895819              0.272778 -0.474054 -1.497900
# 19         -1.149544 -0.394283              0.705562 -0.109550 -0.311102
#
# [20 rows x 51 columns]

# %%
#data.columns

# %%
# (EL Code) Recode Age Ranges (Age ranges were in original format for some reason, recoding for consistency)
def recode_age_range(age_range):
    if age_range in ['18-21']:
        return '18-21'
    elif age_range in ['22-25', '26-29']:
        return '22-29'
    elif age_range in ['30-33', '34-37', '38-41']:
        return '30-41'
    elif age_range in ['42-45']:
        return '42-45'
    elif age_range in ['46+']:
        return '46+'
    else:
        return age_range

# Apply the function to the AGE_RANGE column
data['AGE_RANGE'] = data['AGE_RANGE'].apply(recode_age_range)

# %%
# Make seperate dfs for students and instructors 
students = data[data['OCCUPATION'] == 'Student']
instructors = data[data['OCCUPATION'] == 'Instructor']

# %% [markdown]
# # Analysis of Variance - One-Way ANOVA (Students & Instructors)

# %%
# (EL Code) One-Way Anova for Students 
variables = ['AWARENESS', 'BENEFITS', 'LIMITATIONS', 'IMPLICATIONS',
             'WORK_PRODUCTIVITY', 'PLAGIARISM', 'SOCIAL_IMPACT',
             'HIGHERED_BENEFIT', 'USAGE', 'RESP_USE_TRUST_BENEF', 'TRUST']
factors = ['AGE_RANGE' , 'GENDER']

for factor_name in factors:
    for target_name in variables:
        
        # One-way ANOVA
        formula = f"{target_name} ~ C({factor_name})"
        print(formula)
        
        # Perform the ANOVA
        model = sm.formula.ols(formula, data=students).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        # Perform Tukey's HSD test
        mc = MultiComparison(students[target_name], students[factor_name])
        tukey_result = mc.tukeyhsd()

        print("ANOVA Results:")
        print(anova_table)

        print("Tukey's HSD Test Results:")
        print(tukey_result)
# Out:
# AWARENESS ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    8.065338    4.0  2.229021  0.067211
# Residual      180.916603  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.2381 0.6464 -0.2397  0.716  False
#  18-21  30-41  -0.0989 0.9996 -1.4244 1.2266  False
#  18-21  42-45  -0.6411 0.9622 -3.2675 1.9853  False
#  18-21    46+   1.2566 0.0724 -0.0689 2.5821  False
#  22-29  30-41   -0.337  0.962 -1.7151  1.041  False
#  22-29  42-45  -0.8792  0.892 -3.5326 1.7741  False
#  22-29    46+   1.0184 0.2534 -0.3596 2.3965  False
#  30-41  42-45  -0.5422 0.9863 -3.4694  2.385  False
#  30-41    46+   1.3555 0.2623 -0.4959 3.2068  False
#  42-45    46+   1.8977 0.3854 -1.0296 4.8249  False
# ---------------------------------------------------
# BENEFITS ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    0.369027    4.0  0.089205  0.985748
# Residual      206.841709  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0342 0.9997 -0.4768 0.5452  False
#  18-21  30-41   0.2034 0.9948 -1.2138 1.6207  False
#  18-21  42-45   0.2034 0.9996 -2.6049 3.0117  False
#  18-21    46+   0.2034 0.9948 -1.2138 1.6207  False
#  22-29  30-41   0.1692 0.9978 -1.3043 1.6427  False
#  22-29  42-45   0.1692 0.9998 -2.6679 3.0063  False
#  22-29    46+   0.1692 0.9978 -1.3043 1.6427  False
#  30-41  42-45      0.0    1.0   -3.13   3.13  False
#  30-41    46+      0.0    1.0 -1.9796 1.9796  False
#  42-45    46+      0.0    1.0   -3.13   3.13  False
# ---------------------------------------------------
# LIMITATIONS ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    4.677559    4.0  1.160008  0.329719
# Residual      201.617526  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.1399 0.9407 -0.6444 0.3646  False
#  18-21  30-41  -0.8521 0.4509 -2.2513 0.5471  False
#  18-21  42-45  -1.1183  0.801 -3.8909 1.6543  False
#  18-21    46+   0.2126 0.9936 -1.1866 1.6119  False
#  22-29  30-41  -0.7122 0.6617  -2.167 0.7425  False
#  22-29  42-45  -0.9784  0.872 -3.7794 1.8227  False
#  22-29    46+   0.3525 0.9632 -1.1022 1.8073  False
#  30-41  42-45  -0.2662 0.9993 -3.3564  2.824  False
#  30-41    46+   1.0647 0.5639 -0.8897 3.0191  False
#  42-45    46+   1.3309 0.7596 -1.7593 4.4211  False
# ---------------------------------------------------
# IMPLICATIONS ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F   PR(>F)
# C(AGE_RANGE)    6.400341    4.0  1.603393  0.17487
# Residual      199.587369  200.0       NaN      NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0556 0.9981 -0.4464 0.5575  False
#  18-21  30-41  -0.5058  0.855  -1.898 0.8863  False
#  18-21  42-45  -1.0385 0.8382 -3.7971 1.7201  False
#  18-21    46+  -1.0385 0.2447 -2.4307 0.3537  False
#  22-29  30-41  -0.5614 0.8228 -2.0088  0.886  False
#  22-29  42-45  -1.0941 0.8163  -3.881 1.6928  False
#  22-29    46+  -1.0941 0.2325 -2.5415 0.3533  False
#  30-41  42-45  -0.5326 0.9894 -3.6072 2.5419  False
#  30-41    46+  -0.5326 0.9432 -2.4772 1.4119  False
#  42-45    46+      0.0    1.0 -3.0746 3.0746  False
# ---------------------------------------------------
# WORK_PRODUCTIVITY ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    0.634112    4.0  0.275616  0.893491
# Residual      115.035561  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0033    1.0 -0.3778 0.3843  False
#  18-21  30-41  -0.0175    1.0 -1.0744 1.0395  False
#  18-21  42-45   -0.233 0.9981 -2.3273 1.8613  False
#  18-21    46+   0.3831 0.8561 -0.6738   1.44  False
#  22-29  30-41  -0.0207    1.0 -1.1196 1.0781  False
#  22-29  42-45  -0.2363  0.998 -2.3521 1.8795  False
#  22-29    46+   0.3798 0.8762  -0.719 1.4787  False
#  30-41  42-45  -0.2156 0.9991 -2.5497 2.1186  False
#  30-41    46+   0.4006 0.9451 -1.0757 1.8768  False
#  42-45    46+   0.6161 0.9501  -1.718 2.9503  False
# ---------------------------------------------------
# PLAGIARISM ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    1.440919    4.0  0.475951  0.753366
# Residual      151.372604  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.2037 0.7023 -0.6408 0.2335  False
#  18-21  30-41  -0.2481 0.9802 -1.4605 0.9643  False
#  18-21  42-45   0.0348    1.0 -2.3676 2.4372  False
#  18-21    46+    0.025    1.0 -1.1875 1.2374  False
#  22-29  30-41  -0.0444    1.0 -1.3049 1.2161  False
#  22-29  42-45   0.2385 0.9988 -2.1886 2.6655  False
#  22-29    46+   0.2286 0.9874 -1.0319 1.4891  False
#  30-41  42-45   0.2829 0.9984 -2.3947 2.9605  False
#  30-41    46+    0.273 0.9919 -1.4204 1.9665  False
#  42-45    46+  -0.0099    1.0 -2.6874 2.6677  False
# ---------------------------------------------------
# SOCIAL_IMPACT ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F   PR(>F)
# C(AGE_RANGE)    9.651070    4.0  2.341593  0.05631
# Residual      206.079125  200.0       NaN      NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.3829 0.2388  -0.893 0.1271  False
#  18-21  30-41  -0.9917  0.305 -2.4064 0.4229  False
#  18-21  42-45   0.8855 0.9077 -1.9177 3.6886  False
#  18-21    46+   0.4162 0.9274 -0.9985 1.8308  False
#  22-29  30-41  -0.6088 0.7853 -2.0796 0.8619  False
#  22-29  42-45   1.2684 0.7321 -1.5635 4.1002  False
#  22-29    46+   0.7991 0.5665 -0.6717 2.2698  False
#  30-41  42-45   1.8772 0.4649  -1.247 5.0014  False
#  30-41    46+   1.4079 0.2888  -0.568 3.3838  False
#  42-45    46+  -0.4693 0.9938 -3.5935 2.6549  False
# ---------------------------------------------------
# HIGHERED_BENEFIT ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    4.481885    4.0  1.010048  0.403327
# Residual      221.864974  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0226    1.0 -0.5066 0.5518  False
#  18-21  30-41  -0.4987 0.8829 -1.9665 0.9691  False
#  18-21  42-45   0.2156 0.9996 -2.6929 3.1241  False
#  18-21    46+     0.93 0.4094 -0.5379 2.3978  False
#  22-29  30-41  -0.5213 0.8808 -2.0473 1.0048  False
#  22-29  42-45   0.1931 0.9998 -2.7453 3.1314  False
#  22-29    46+   0.9074 0.4757 -0.6187 2.4334  False
#  30-41  42-45   0.7143 0.9739 -2.5273  3.956  False
#  30-41    46+   1.4287  0.311 -0.6215 3.4788  False
#  42-45    46+   0.7143 0.9739 -2.5273  3.956  False
# ---------------------------------------------------
# USAGE ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    2.347281    4.0  0.667865  0.615002
# Residual      175.730173  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0409 0.9993 -0.4301 0.5119  False
#  18-21  30-41   0.6254 0.6804 -0.6809 1.9318  False
#  18-21  42-45  -0.8659 0.8886 -3.4544 1.7226  False
#  18-21    46+   0.0876 0.9997 -1.2187 1.3939  False
#  22-29  30-41   0.5846 0.7601 -0.7736 1.9427  False
#  22-29  42-45  -0.9068 0.8749 -3.5218 1.7082  False
#  22-29    46+   0.0467    1.0 -1.3114 1.4049  False
#  30-41  42-45  -1.4914 0.6135 -4.3763 1.3936  False
#  30-41    46+  -0.5378 0.9269 -2.3625 1.2868  False
#  42-45    46+   0.9535 0.8929 -1.9314 3.8385  False
# ---------------------------------------------------
# RESP_USE_TRUST_BENEF ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    3.057636    4.0  1.206057  0.309456
# Residual      126.761705  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29    0.071 0.9884  -0.329  0.471  False
#  18-21  30-41   0.2682 0.9635 -0.8412 1.3777  False
#  18-21  42-45  -0.2647 0.9974 -2.4632 1.9337  False
#  18-21    46+   0.8269 0.2455 -0.2826 1.9364  False
#  22-29  30-41   0.1973 0.9899 -0.9562 1.3508  False
#  22-29  42-45  -0.3357 0.9937 -2.5567 1.8853  False
#  22-29    46+   0.7559 0.3741 -0.3976 1.9094  False
#  30-41  42-45   -0.533 0.9751 -2.9832 1.9173  False
#  30-41    46+   0.5587 0.8585  -0.991 2.1083  False
#  42-45    46+   1.0916  0.736 -1.3586 3.5419  False
# ---------------------------------------------------
# TRUST ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq     df         F    PR(>F)
# C(AGE_RANGE)    8.516802    4.0  2.686499  0.032533
# Residual      158.511169  200.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0712 0.9923 -0.3761 0.5185  False
#  18-21  30-41   0.1645 0.9962 -1.0761 1.4052  False
#  18-21  42-45   1.0233 0.7818 -1.4351 3.4818  False
#  18-21    46+   1.3826 0.0205  0.1419 2.6233   True
#  22-29  30-41   0.0933 0.9996 -1.1966 1.3832  False
#  22-29  42-45   0.9521  0.829 -1.5315 3.4357  False
#  22-29    46+   1.3114 0.0442  0.0215 2.6013   True
#  30-41  42-45   0.8588 0.9101 -1.8812 3.5988  False
#  30-41    46+   1.2181 0.3023 -0.5148  2.951  False
#  42-45    46+   0.3593 0.9963 -2.3807 3.0993  False
# ---------------------------------------------------
# AWARENESS ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)   16.821174    3.0  6.546315  0.000303
# Residual   172.160767  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.5744 0.0001 -0.9188 -0.2301   True
#                    Female Non-binary / third gender  -0.3771  0.725 -1.3148  0.5606  False
#                    Female         Prefer not to say  -0.7257 0.4171 -1.9484  0.4971  False
#                      Male Non-binary / third gender   0.1973  0.948 -0.7417  1.1363  False
#                      Male         Prefer not to say  -0.1512 0.9886  -1.375  1.0725  False
# Non-binary / third gender         Prefer not to say  -0.3486 0.9317 -1.8513  1.1542  False
# ------------------------------------------------------------------------------------------
# BENEFITS ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    6.812334    3.0  2.277595  0.080811
# Residual   200.398403  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.3633 0.0578 -0.7349 0.0082  False
#                    Female Non-binary / third gender   0.0211 0.9999 -0.9906 1.0328  False
#                    Female         Prefer not to say   0.0211    1.0 -1.2982 1.3403  False
#                      Male Non-binary / third gender   0.3844 0.7593 -0.6287 1.3975  False
#                      Male         Prefer not to say   0.3844 0.8748 -0.9359 1.7048  False
# Non-binary / third gender         Prefer not to say      0.0    1.0 -1.6213 1.6213  False
# -----------------------------------------------------------------------------------------
# LIMITATIONS ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    4.711269    3.0  1.565875  0.198868
# Residual   201.583817  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0238 0.9984 -0.3488 0.3964  False
#                    Female Non-binary / third gender  -0.7928 0.1826 -1.8074 0.2219  False
#                    Female         Prefer not to say  -0.2984 0.9367 -1.6216 1.0247  False
#                      Male Non-binary / third gender  -0.8165 0.1625 -1.8326 0.1995  False
#                      Male         Prefer not to say  -0.3222 0.9222 -1.6464  1.002  False
# Non-binary / third gender         Prefer not to say   0.4943 0.8601 -1.1318 2.1205  False
# -----------------------------------------------------------------------------------------
# IMPLICATIONS ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F   PR(>F)
# C(GENDER)    5.978083    3.0  2.002562  0.11485
# Residual   200.009627  201.0       NaN      NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   -0.035 0.9949 -0.4062 0.3362  False
#                    Female Non-binary / third gender   0.4888 0.5939 -0.5219 1.4995  False
#                    Female         Prefer not to say   -1.033 0.1803  -2.351  0.285  False
#                      Male Non-binary / third gender   0.5238 0.5381 -0.4883 1.5359  False
#                      Male         Prefer not to say   -0.998 0.2067 -2.3171  0.321  False
# Non-binary / third gender         Prefer not to say  -1.5218  0.074 -3.1416 0.0979  False
# -----------------------------------------------------------------------------------------
# WORK_PRODUCTIVITY ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    4.237168    3.0  2.547643  0.057053
# Residual   111.432506  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2637 0.0685 -0.5407 0.0134  False
#                    Female Non-binary / third gender  -0.1005 0.9858 -0.8549 0.6539  False
#                    Female         Prefer not to say   0.3404 0.8067 -0.6433 1.3242  False
#                      Male Non-binary / third gender   0.1632 0.9438 -0.5923 0.9186  False
#                      Male         Prefer not to say   0.6041 0.3869 -0.3804 1.5887  False
# Non-binary / third gender         Prefer not to say   0.4409 0.7807 -0.7681 1.6499  False
# -----------------------------------------------------------------------------------------
# PLAGIARISM ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    1.777721    3.0  0.788603  0.501533
# Residual   151.035802  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0682  0.947 -0.2543 0.3908  False
#                    Female Non-binary / third gender   0.4194 0.6041 -0.4589 1.2977  False
#                    Female         Prefer not to say  -0.3261 0.8818 -1.4714 0.8192  False
#                      Male Non-binary / third gender   0.3511 0.7295 -0.5284 1.2307  False
#                      Male         Prefer not to say  -0.3943 0.8094 -1.5406 0.7519  False
# Non-binary / third gender         Prefer not to say  -0.7455 0.5184  -2.153 0.6621  False
# -----------------------------------------------------------------------------------------
# SOCIAL_IMPACT ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    8.481630    3.0  2.741969  0.044347
# Residual   207.248565  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.0407 0.9924 -0.4185 0.3371  False
#                    Female Non-binary / third gender  -0.1056 0.9934 -1.1345 0.9232  False
#                    Female         Prefer not to say   1.4363 0.0306  0.0947  2.778   True
#                      Male Non-binary / third gender  -0.0649 0.9984 -1.0952 0.9653  False
#                      Male         Prefer not to say   1.4771 0.0247  0.1343 2.8198   True
# Non-binary / third gender         Prefer not to say    1.542 0.0761 -0.1068 3.1908  False
# -----------------------------------------------------------------------------------------
# HIGHERED_BENEFIT ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    7.724685    3.0  2.367344  0.072002
# Residual   218.622174  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2888 0.2197 -0.6768 0.0993  False
#                    Female Non-binary / third gender   -0.336 0.8431 -1.3927 0.7207  False
#                    Female         Prefer not to say   0.7865 0.4523 -0.5915 2.1644  False
#                      Male Non-binary / third gender  -0.0473 0.9994 -1.1054 1.0109  False
#                      Male         Prefer not to say   1.0752 0.1841 -0.3038 2.4543  False
# Non-binary / third gender         Prefer not to say   1.1225 0.3174  -0.571  2.816  False
# -----------------------------------------------------------------------------------------
# USAGE ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)   21.750625    3.0  9.322084  0.000008
# Residual   156.326829  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.6648    0.0  -0.993 -0.3367   True
#                    Female Non-binary / third gender  -0.3935 0.6646 -1.2871     0.5  False
#                    Female         Prefer not to say  -0.6003  0.542 -1.7655  0.5649  False
#                      Male Non-binary / third gender   0.2713  0.861 -0.6235  1.1661  False
#                      Male         Prefer not to say   0.0645 0.9989 -1.1016  1.2307  False
# Non-binary / third gender         Prefer not to say  -0.2067 0.9821 -1.6388  1.2253  False
# ------------------------------------------------------------------------------------------
# RESP_USE_TRUST_BENEF ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df        F    PR(>F)
# C(GENDER)   11.332586    3.0  6.40817  0.000363
# Residual   118.486755  201.0      NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.4273 0.0008  -0.713 -0.1417   True
#                    Female Non-binary / third gender  -0.1297 0.9729 -0.9076  0.6482  False
#                    Female         Prefer not to say   0.5818 0.4479 -0.4326  1.5962  False
#                      Male Non-binary / third gender   0.2976 0.7554 -0.4814  1.0766  False
#                      Male         Prefer not to say   1.0091  0.052 -0.0061  2.0244  False
# Non-binary / third gender         Prefer not to say   0.7115 0.4524 -0.5352  1.9582  False
# ------------------------------------------------------------------------------------------
# TRUST ~ C(GENDER)
# ANOVA Results:
#                sum_sq     df         F    PR(>F)
# C(GENDER)    6.405552    3.0  2.671931  0.048568
# Residual   160.622420  201.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0389 0.9903 -0.2937 0.3715  False
#                    Female Non-binary / third gender  -0.1563 0.9701  -1.062 0.7494  False
#                    Female         Prefer not to say   1.2626  0.031  0.0815 2.4437   True
#                      Male Non-binary / third gender  -0.1952 0.9444 -1.1022 0.7118  False
#                      Male         Prefer not to say   1.2237 0.0393  0.0416 2.4058   True
# Non-binary / third gender         Prefer not to say   1.4189  0.058 -0.0327 2.8704  False
# -----------------------------------------------------------------------------------------

# %%
# (EL Code) One-Way Anova for Instructors
variables = ['AWARENESS', 'BENEFITS', 'LIMITATIONS', 'IMPLICATIONS',
             'WORK_PRODUCTIVITY', 'PLAGIARISM', 'SOCIAL_IMPACT',
             'HIGHERED_BENEFIT', 'USAGE', 'RESP_USE_TRUST_BENEF', 'TRUST']
factors = ['AGE_RANGE' , 'GENDER']

for factor_name in factors:
    for target_name in variables:
        
        # One-way ANOVA
        formula = f"{target_name} ~ C({factor_name})"
        print(formula)
        
        # Perform the ANOVA
        model = sm.formula.ols(formula, data=instructors).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        # Perform Tukey's HSD test
        mc = MultiComparison(instructors[target_name], instructors[factor_name])
        tukey_result = mc.tukeyhsd()

        print("ANOVA Results:")
        print(anova_table)

        print("Tukey's HSD Test Results:")
        print(tukey_result)
# Out:
# AWARENESS ~ C(AGE_RANGE)
# ANOVA Results:
#                   sum_sq    df        F    PR(>F)
# C(AGE_RANGE)    3.377481   4.0  0.72592  0.576463
# Residual      107.011922  92.0      NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.1668 0.9999 -2.9475 3.2812  False
#  18-21  30-41  -0.2357 0.9995 -3.3014 2.8299  False
#  18-21  42-45  -0.6024 0.9841 -3.7658  2.561  False
#  18-21    46+  -0.2552 0.9993 -3.2855 2.7752  False
#  22-29  30-41  -0.4026 0.8185 -1.4439 0.6388  False
#  22-29  42-45  -0.7693  0.473 -2.0706 0.5321  False
#  22-29    46+   -0.422 0.7165 -1.3544 0.5104  False
#  30-41  42-45  -0.3667  0.909 -1.5467 0.8133  False
#  30-41    46+  -0.0194    1.0 -0.7732 0.7344  False
#  42-45    46+   0.3473 0.8997 -0.7377 1.4323  False
# ---------------------------------------------------
# BENEFITS ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   5.990474   4.0  1.612161  0.177858
# Residual      85.463516  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.6421 0.9677 -2.1411 3.4253  False
#  18-21  30-41   0.9527  0.869 -1.7869 3.6923  False
#  18-21  42-45   0.8116 0.9303 -2.0155 3.6386  False
#  18-21    46+    1.248 0.7026 -1.4601 3.9561  False
#  22-29  30-41   0.3106 0.8851   -0.62 1.2412  False
#  22-29  42-45   0.1694 0.9942 -0.9935 1.3324  False
#  22-29    46+   0.6059 0.2632 -0.2274 1.4392  False
#  30-41  42-45  -0.1411 0.9958 -1.1956 0.9133  False
#  30-41    46+   0.2953 0.7398 -0.3783 0.9689  False
#  42-45    46+   0.4365 0.7206 -0.5332 1.4061  False
# ---------------------------------------------------
# LIMITATIONS ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   7.002205   4.0  1.874197  0.121601
# Residual      85.930525  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.3276 0.9975 -2.4632 3.1184  False
#  18-21  30-41  -0.5555 0.9801 -3.3026 2.1916  False
#  18-21  42-45      0.0    1.0 -2.8347 2.8347  False
#  18-21    46+  -0.1253 0.9999 -2.8408 2.5902  False
#  22-29  30-41  -0.8831 0.0726 -1.8163   0.05  False
#  22-29  42-45  -0.3276 0.9353 -1.4937 0.8385  False
#  22-29    46+  -0.4529 0.5599 -1.2884 0.3827  False
#  30-41  42-45   0.5555 0.5896 -0.5019 1.6129  False
#  30-41    46+   0.4302 0.3958 -0.2452 1.1057  False
#  42-45    46+  -0.1253 0.9964 -1.0976  0.847  False
# ---------------------------------------------------
# IMPLICATIONS ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   3.119540   4.0  1.047372  0.387256
# Residual      68.504216  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.8195 0.8904 -1.6723 3.3112  False
#  18-21  30-41   0.2316 0.9989 -2.2212 2.6844  False
#  18-21  42-45   0.4735 0.9851 -2.0576 3.0045  False
#  18-21    46+   0.3969  0.991 -2.0277 2.8214  False
#  22-29  30-41  -0.5879 0.2921  -1.421 0.2453  False
#  22-29  42-45   -0.346 0.8867 -1.3872 0.6952  False
#  22-29    46+  -0.4226 0.5163 -1.1686 0.3234  False
#  30-41  42-45   0.2419 0.9531 -0.7022  1.186  False
#  30-41    46+   0.1653 0.9406 -0.4378 0.7684  False
#  42-45    46+  -0.0766 0.9992 -0.9447 0.7915  False
# ---------------------------------------------------
# WORK_PRODUCTIVITY ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   2.658962   4.0  1.203905  0.314549
# Residual      50.798140  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0528    1.0  -2.093 2.1985  False
#  18-21  30-41   0.3792 0.9872  -1.733 2.4913  False
#  18-21  42-45    0.453 0.9779 -1.7265 2.6326  False
#  18-21    46+   0.5356 0.9528 -1.5523 2.6234  False
#  22-29  30-41   0.3264 0.7126 -0.3911 1.0439  False
#  22-29  42-45   0.4003 0.7268 -0.4964 1.2969  False
#  22-29    46+   0.4828 0.2327 -0.1596 1.1252  False
#  30-41  42-45   0.0738 0.9991 -0.7391 0.8868  False
#  30-41    46+   0.1564  0.918 -0.3629 0.6757  False
#  42-45    46+   0.0826  0.998  -0.665 0.8301  False
# ---------------------------------------------------
# PLAGIARISM ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   3.696248   4.0  1.864815  0.123285
# Residual      45.588278  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.2973 0.9941 -2.3301 1.7354  False
#  18-21  30-41  -0.7208 0.8536 -2.7217 1.2801  False
#  18-21  42-45  -0.6734 0.8934 -2.7381 1.3914  False
#  18-21    46+   -0.848 0.7553 -2.8259 1.1299  False
#  22-29  30-41  -0.4235 0.4187 -1.1032 0.2562  False
#  22-29  42-45   -0.376 0.7329 -1.2254 0.4734  False
#  22-29    46+  -0.5507 0.0955 -1.1593 0.0579  False
#  30-41  42-45   0.0475 0.9998 -0.7227 0.8176  False
#  30-41    46+  -0.1272 0.9515 -0.6192 0.3648  False
#  42-45    46+  -0.1747  0.959 -0.8829 0.5335  False
# ---------------------------------------------------
# SOCIAL_IMPACT ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   1.964654   4.0  0.542707  0.704752
# Residual      83.262374  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.8664 0.9044 -3.6135 1.8807  False
#  18-21  30-41   -1.061 0.8103 -3.7651 1.6431  False
#  18-21  42-45  -1.2515 0.7233 -4.0418 1.5389  False
#  18-21    46+   -0.957 0.8564   -3.63  1.716  False
#  22-29  30-41  -0.1946 0.9763 -1.1132 0.7239  False
#  22-29  42-45  -0.3851 0.8832  -1.533 0.7628  False
#  22-29    46+  -0.0906  0.998 -0.9131 0.7319  False
#  30-41  42-45  -0.1904 0.9863 -1.2313 0.8504  False
#  30-41    46+    0.104 0.9924 -0.5609 0.7689  False
#  42-45    46+   0.2945  0.912 -0.6626 1.2516  False
# ---------------------------------------------------
# HIGHERED_BENEFIT ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   2.258784   4.0  0.757212  0.555788
# Residual      68.609649  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.6594 0.9476 -3.1531 1.8343  False
#  18-21  30-41  -0.6212 0.9551 -3.0758 1.8335  False
#  18-21  42-45  -0.3175 0.9968 -2.8505 2.2155  False
#  18-21    46+  -0.3362 0.9952 -2.7626 2.0903  False
#  22-29  30-41   0.0382 0.9999 -0.7956  0.872  False
#  22-29  42-45   0.3419 0.8912 -0.7001 1.3839  False
#  22-29    46+   0.3232 0.7487 -0.4234 1.0698  False
#  30-41  42-45   0.3037 0.8983 -0.6411 1.2485  False
#  30-41    46+    0.285 0.6833 -0.3186 0.8886  False
#  42-45    46+  -0.0187    1.0 -0.8875 0.8501  False
# ---------------------------------------------------
# USAGE ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F   PR(>F)
# C(AGE_RANGE)   3.241092   4.0  1.231246  0.30311
# Residual      60.544460  92.0       NaN      NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.6562 0.9359 -2.9987 1.6864  False
#  18-21  30-41  -0.9625 0.7731 -3.2684 1.3433  False
#  18-21  42-45  -0.7435 0.9073 -3.1229  1.636  False
#  18-21    46+  -0.5469 0.9628 -2.8262 1.7325  False
#  22-29  30-41  -0.3064 0.8121 -1.0896 0.4769  False
#  22-29  42-45  -0.0873 0.9991 -1.0661 0.8916  False
#  22-29    46+   0.1093 0.9925  -0.592 0.8107  False
#  30-41  42-45   0.2191 0.9589 -0.6685 1.1066  False
#  30-41    46+   0.4157 0.2554 -0.1513 0.9827  False
#  42-45    46+   0.1966 0.9623 -0.6195 1.0128  False
# ---------------------------------------------------
# RESP_USE_TRUST_BENEF ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df        F    PR(>F)
# C(AGE_RANGE)   3.727335   4.0  2.02614  0.097206
# Residual      42.311338  92.0      NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.1137 0.9998 -1.8446  2.072  False
#  18-21  30-41   0.1099 0.9999 -1.8177 2.0376  False
#  18-21  42-45   0.2872 0.9944  -1.702 2.2763  False
#  18-21    46+   0.5228 0.9404 -1.3827 2.4283  False
#  22-29  30-41  -0.0037    1.0 -0.6585 0.6511  False
#  22-29  42-45   0.1735 0.9763 -0.6448 0.9918  False
#  22-29    46+   0.4091  0.303 -0.1772 0.9954  False
#  30-41  42-45   0.1772 0.9634 -0.5647 0.9192  False
#  30-41    46+   0.4129 0.1182 -0.0611 0.8868  False
#  42-45    46+   0.2356 0.8718 -0.4467 0.9179  False
# ---------------------------------------------------
# TRUST ~ C(AGE_RANGE)
# ANOVA Results:
#                  sum_sq    df         F    PR(>F)
# C(AGE_RANGE)   1.845134   4.0  0.612496  0.654688
# Residual      69.287101  92.0       NaN       NaN
# Tukey's HSD Test Results:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.2259 0.9991 -2.2801 2.7318  False
#  18-21  30-41   0.6545 0.9469 -1.8122 3.1213  False
#  18-21  42-45   0.5344 0.9771  -2.011 3.0799  False
#  18-21    46+   0.5451 0.9712 -1.8933 2.9834  False
#  22-29  30-41   0.4287 0.6142 -0.4092 1.2666  False
#  22-29  42-45   0.3086 0.9238 -0.7386 1.3557  False
#  22-29    46+   0.3192 0.7606 -0.4311 1.0695  False
#  30-41  42-45  -0.1201 0.9967 -1.0696 0.8293  False
#  30-41    46+  -0.1095  0.987  -0.716  0.497  False
#  42-45    46+   0.0106    1.0 -0.8624 0.8837  False
# ---------------------------------------------------
# AWARENESS ~ C(GENDER)
# ANOVA Results:
#                sum_sq    df         F    PR(>F)
# C(GENDER)    2.045191   3.0  0.585181  0.626212
# Residual   108.344212  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2791 0.6034 -0.8682 0.3099  False
#                    Female Non-binary / third gender  -0.4418 0.9412 -2.4751 1.5915  False
#                    Female         Prefer not to say   0.1004 0.9997 -2.7493 2.9501  False
#                      Male Non-binary / third gender  -0.1627 0.9968 -2.2086 1.8833  False
#                      Male         Prefer not to say   0.3795 0.9855 -2.4792 3.2383  False
# Non-binary / third gender         Prefer not to say   0.5422 0.9766 -2.9161 4.0005  False
# -----------------------------------------------------------------------------------------
# BENEFITS ~ C(GENDER)
# ANOVA Results:
#              sum_sq    df         F    PR(>F)
# C(GENDER)   7.48709   3.0  2.764182  0.046309
# Residual   83.96690  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   -0.428 0.1425 -0.9466 0.0906  False
#                    Female Non-binary / third gender  -1.2367 0.2764 -3.0266 0.5533  False
#                    Female         Prefer not to say   0.8502 0.8118 -1.6585 3.3589  False
#                      Male Non-binary / third gender  -0.8087 0.6443 -2.6098 0.9925  False
#                      Male         Prefer not to say   1.2782 0.5472 -1.2385 3.7949  False
# Non-binary / third gender         Prefer not to say   2.0869 0.2831 -0.9576 5.1313  False
# -----------------------------------------------------------------------------------------
# LIMITATIONS ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   4.539411   3.0  1.591995  0.196601
# Residual   88.393319  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2928 0.4781 -0.8249 0.2393  False
#                    Female Non-binary / third gender  -1.0647 0.4318 -2.9013 0.7718  False
#                    Female         Prefer not to say  -1.0647 0.7013 -3.6387 1.5093  False
#                      Male Non-binary / third gender  -0.7719 0.6948 -2.6199 1.0761  False
#                      Male         Prefer not to say  -0.7719 0.8624 -3.3541 1.8102  False
# Non-binary / third gender         Prefer not to say      0.0    1.0 -3.1237 3.1237  False
# -----------------------------------------------------------------------------------------
# IMPLICATIONS ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   0.204350   3.0  0.088699  0.966085
# Residual   71.419406  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0118 0.9999 -0.4664 0.4901  False
#                    Female Non-binary / third gender   0.1184 0.9976 -1.5325 1.7692  False
#                    Female         Prefer not to say  -0.4143 0.9658  -2.728 1.8994  False
#                      Male Non-binary / third gender   0.1065 0.9983 -1.5546 1.7676  False
#                      Male         Prefer not to say  -0.4261 0.9633 -2.7472 1.8949  False
# Non-binary / third gender         Prefer not to say  -0.5326 0.9597 -3.3404 2.2752  False
# -----------------------------------------------------------------------------------------
# WORK_PRODUCTIVITY ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   4.405761   3.0  2.784401  0.045159
# Residual   49.051341  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.3362 0.1256 -0.7326 0.0601  False
#                    Female Non-binary / third gender   0.3166 0.9301 -1.0515 1.6847  False
#                    Female         Prefer not to say   1.0533 0.4797 -0.8641 2.9708  False
#                      Male Non-binary / third gender   0.6528 0.6028 -0.7238 2.0295  False
#                      Male         Prefer not to say   1.3896 0.2394  -0.534 3.3131  False
# Non-binary / third gender         Prefer not to say   0.7367 0.8409 -1.5902 3.0637  False
# -----------------------------------------------------------------------------------------
# PLAGIARISM ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   0.624967   3.0  0.398154  0.754635
# Residual   48.659558  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0266  0.998 -0.3682 0.4214  False
#                    Female Non-binary / third gender   0.3136 0.9312 -1.0491 1.6762  False
#                    Female         Prefer not to say  -0.6414 0.8159 -2.5512 1.2684  False
#                      Male Non-binary / third gender    0.287  0.947 -1.0841 1.6581  False
#                      Male         Prefer not to say   -0.668 0.7984 -2.5838 1.2479  False
# Non-binary / third gender         Prefer not to say   -0.955 0.7038 -3.2726 1.3627  False
# -----------------------------------------------------------------------------------------
# SOCIAL_IMPACT ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   1.071561   3.0  0.394726  0.757086
# Residual   84.155467  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.0591 0.9908 -0.5782 0.4601  False
#                    Female Non-binary / third gender   0.0348    1.0 -1.7572 1.8268  False
#                    Female         Prefer not to say   0.9734 0.7417 -1.5382 3.4849  False
#                      Male Non-binary / third gender   0.0939 0.9991 -1.7093  1.897  False
#                      Male         Prefer not to say   1.0325 0.7073  -1.487  3.552  False
# Non-binary / third gender         Prefer not to say   0.9386 0.8516 -2.1093 3.9865  False
# -----------------------------------------------------------------------------------------
# HIGHERED_BENEFIT ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   2.272328   3.0  1.026912  0.384437
# Residual   68.596105  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2897 0.3742 -0.7584  0.179  False
#                    Female Non-binary / third gender  -0.3968 0.9182 -2.0147  1.221  False
#                    Female         Prefer not to say   0.3175 0.9831   -1.95  2.585  False
#                      Male Non-binary / third gender  -0.1071 0.9982 -1.7351 1.5208  False
#                      Male         Prefer not to say   0.6072 0.8975 -1.6675 2.8819  False
# Non-binary / third gender         Prefer not to say   0.7143 0.9048 -2.0374 3.4661  False
# -----------------------------------------------------------------------------------------
# USAGE ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F   PR(>F)
# C(GENDER)  12.156403   3.0  7.299142  0.00019
# Residual   51.629148  93.0       NaN      NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.6695 0.0002 -1.0761 -0.2629   True
#                    Female Non-binary / third gender   0.3917 0.8848 -1.0119  1.7953  False
#                    Female         Prefer not to say  -1.2557 0.3454 -3.2229  0.7115  False
#                      Male Non-binary / third gender   1.0612 0.2085 -0.3511  2.4736  False
#                      Male         Prefer not to say  -0.5862 0.8646 -2.5596  1.3872  False
# Non-binary / third gender         Prefer not to say  -1.6474 0.2774 -4.0347  0.7399  False
# ------------------------------------------------------------------------------------------
# RESP_USE_TRUST_BENEF ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F    PR(>F)
# C(GENDER)   3.094703   3.0  2.233976  0.089431
# Residual   42.943970  93.0       NaN       NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.3495 0.0722 -0.7204 0.0214  False
#                    Female Non-binary / third gender  -0.2592 0.9517 -1.5393 1.0209  False
#                    Female         Prefer not to say   0.3654 0.9509 -1.4287 2.1595  False
#                      Male Non-binary / third gender   0.0903 0.9978 -1.1978 1.3784  False
#                      Male         Prefer not to say   0.7149  0.727 -1.0849 2.5147  False
# Non-binary / third gender         Prefer not to say   0.6246 0.8762 -1.5527 2.8018  False
# -----------------------------------------------------------------------------------------
# TRUST ~ C(GENDER)
# ANOVA Results:
#               sum_sq    df         F   PR(>F)
# C(GENDER)   2.598901   3.0  1.175573  0.32337
# Residual   68.533334  93.0       NaN      NaN
# Tukey's HSD Test Results:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0856 0.9638 -0.3829 0.5541  False
#                    Female Non-binary / third gender  -0.0972 0.9986 -1.7144 1.5199  False
#                    Female         Prefer not to say   1.5895 0.2638  -0.677 3.8559  False
#                      Male Non-binary / third gender  -0.1828 0.9911   -1.81 1.4444  False
#                      Male         Prefer not to say   1.5039 0.3139 -0.7698 3.7776  False
# Non-binary / third gender         Prefer not to say   1.6867 0.3813 -1.0638 4.4372  False
# -----------------------------------------------------------------------------------------

# %% [markdown]
# # Analysis of Variance - Multi-Way ANOVA (Students & Instructors)

# %%
# (EL Code) 2-Way ANOVA for Students - Main Effects & Interactions 

# Define the list of variables
variables = ['AWARENESS', 'BENEFITS', 'LIMITATIONS', 'IMPLICATIONS',
             'WORK_PRODUCTIVITY', 'PLAGIARISM', 'SOCIAL_IMPACT',
             'HIGHERED_BENEFIT', 'USAGE', 'RESP_USE_TRUST_BENEF', 'TRUST']

# Define the factors
factors = ['AGE_RANGE', 'GENDER']

for target_name in variables:
    # Multi-way ANOVA
    formula = f"{target_name} ~ C(AGE_RANGE) * C(GENDER)"
    print(formula)

    # Perform the multi-way ANOVA
    model = sm.formula.ols(formula, data=students).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)

    print(f"Multi-way ANOVA Results:")
    print(anova_table)

    # Perform Tukey's HSD for pairwise comparisons for each factor
    for factor in factors:
        mc = MultiComparison(students[target_name], students[factor])
        result = mc.tukeyhsd()

        print(f"Tukey's HSD Results for {factor}:")
        print(result)
# Out:
# AWARENESS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   12.779228   12.0  1.299751  0.265629
# Residual                158.132230  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.2381 0.6464 -0.2397  0.716  False
#  18-21  30-41  -0.0989 0.9996 -1.4244 1.2266  False
#  18-21  42-45  -0.6411 0.9622 -3.2675 1.9853  False
#  18-21    46+   1.2566 0.0724 -0.0689 2.5821  False
#  22-29  30-41   -0.337  0.962 -1.7151  1.041  False
#  22-29  42-45  -0.8792  0.892 -3.5326 1.7741  False
#  22-29    46+   1.0184 0.2534 -0.3596 2.3965  False
#  30-41  42-45  -0.5422 0.9863 -3.4694  2.385  False
#  30-41    46+   1.3555 0.2623 -0.4959 3.2068  False
#  42-45    46+   1.8977 0.3854 -1.0296 4.8249  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.5744 0.0001 -0.9188 -0.2301   True
#                    Female Non-binary / third gender  -0.3771  0.725 -1.3148  0.5606  False
#                    Female         Prefer not to say  -0.7257 0.4171 -1.9484  0.4971  False
#                      Male Non-binary / third gender   0.1973  0.948 -0.7417  1.1363  False
#                      Male         Prefer not to say  -0.1512 0.9886  -1.375  1.0725  False
# Non-binary / third gender         Prefer not to say  -0.3486 0.9317 -1.8513  1.1542  False
# ------------------------------------------------------------------------------------------
# BENEFITS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   22.293613   12.0  1.876863  0.100086
# Residual                191.039864  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0342 0.9997 -0.4768 0.5452  False
#  18-21  30-41   0.2034 0.9948 -1.2138 1.6207  False
#  18-21  42-45   0.2034 0.9996 -2.6049 3.0117  False
#  18-21    46+   0.2034 0.9948 -1.2138 1.6207  False
#  22-29  30-41   0.1692 0.9978 -1.3043 1.6427  False
#  22-29  42-45   0.1692 0.9998 -2.6679 3.0063  False
#  22-29    46+   0.1692 0.9978 -1.3043 1.6427  False
#  30-41  42-45      0.0    1.0   -3.13   3.13  False
#  30-41    46+      0.0    1.0 -1.9796 1.9796  False
#  42-45    46+      0.0    1.0   -3.13   3.13  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.3633 0.0578 -0.7349 0.0082  False
#                    Female Non-binary / third gender   0.0211 0.9999 -0.9906 1.0328  False
#                    Female         Prefer not to say   0.0211    1.0 -1.2982 1.3403  False
#                      Male Non-binary / third gender   0.3844 0.7593 -0.6287 1.3975  False
#                      Male         Prefer not to say   0.3844 0.8748 -0.9359 1.7048  False
# Non-binary / third gender         Prefer not to say      0.0    1.0 -1.6213 1.6213  False
# -----------------------------------------------------------------------------------------
# LIMITATIONS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df        F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0      NaN       NaN
# C(GENDER)                      NaN    3.0      NaN       NaN
# C(AGE_RANGE):C(GENDER)    9.322800   12.0  0.77281  0.570406
# Residual                194.021312  193.0      NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.1399 0.9407 -0.6444 0.3646  False
#  18-21  30-41  -0.8521 0.4509 -2.2513 0.5471  False
#  18-21  42-45  -1.1183  0.801 -3.8909 1.6543  False
#  18-21    46+   0.2126 0.9936 -1.1866 1.6119  False
#  22-29  30-41  -0.7122 0.6617  -2.167 0.7425  False
#  22-29  42-45  -0.9784  0.872 -3.7794 1.8227  False
#  22-29    46+   0.3525 0.9632 -1.1022 1.8073  False
#  30-41  42-45  -0.2662 0.9993 -3.3564  2.824  False
#  30-41    46+   1.0647 0.5639 -0.8897 3.0191  False
#  42-45    46+   1.3309 0.7596 -1.7593 4.4211  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0238 0.9984 -0.3488 0.3964  False
#                    Female Non-binary / third gender  -0.7928 0.1826 -1.8074 0.2219  False
#                    Female         Prefer not to say  -0.2984 0.9367 -1.6216 1.0247  False
#                      Male Non-binary / third gender  -0.8165 0.1625 -1.8326 0.1995  False
#                      Male         Prefer not to say  -0.3222 0.9222 -1.6464  1.002  False
# Non-binary / third gender         Prefer not to say   0.4943 0.8601 -1.1318 2.1205  False
# -----------------------------------------------------------------------------------------
# IMPLICATIONS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    7.177894   12.0  0.597136  0.702183
# Residual                193.330299  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0556 0.9981 -0.4464 0.5575  False
#  18-21  30-41  -0.5058  0.855  -1.898 0.8863  False
#  18-21  42-45  -1.0385 0.8382 -3.7971 1.7201  False
#  18-21    46+  -1.0385 0.2447 -2.4307 0.3537  False
#  22-29  30-41  -0.5614 0.8228 -2.0088  0.886  False
#  22-29  42-45  -1.0941 0.8163  -3.881 1.6928  False
#  22-29    46+  -1.0941 0.2325 -2.5415 0.3533  False
#  30-41  42-45  -0.5326 0.9894 -3.6072 2.5419  False
#  30-41    46+  -0.5326 0.9432 -2.4772 1.4119  False
#  42-45    46+      0.0    1.0 -3.0746 3.0746  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   -0.035 0.9949 -0.4062 0.3362  False
#                    Female Non-binary / third gender   0.4888 0.5939 -0.5219 1.4995  False
#                    Female         Prefer not to say   -1.033 0.1803  -2.351  0.285  False
#                      Male Non-binary / third gender   0.5238 0.5381 -0.4883 1.5359  False
#                      Male         Prefer not to say   -0.998 0.2067 -2.3171  0.321  False
# Non-binary / third gender         Prefer not to say  -1.5218  0.074 -3.1416 0.0979  False
# -----------------------------------------------------------------------------------------
# WORK_PRODUCTIVITY ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df       F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0     NaN       NaN
# C(GENDER)                      NaN    3.0     NaN       NaN
# C(AGE_RANGE):C(GENDER)    4.534153   12.0  0.6677  0.648401
# Residual                109.217087  193.0     NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0033    1.0 -0.3778 0.3843  False
#  18-21  30-41  -0.0175    1.0 -1.0744 1.0395  False
#  18-21  42-45   -0.233 0.9981 -2.3273 1.8613  False
#  18-21    46+   0.3831 0.8561 -0.6738   1.44  False
#  22-29  30-41  -0.0207    1.0 -1.1196 1.0781  False
#  22-29  42-45  -0.2363  0.998 -2.3521 1.8795  False
#  22-29    46+   0.3798 0.8762  -0.719 1.4787  False
#  30-41  42-45  -0.2156 0.9991 -2.5497 2.1186  False
#  30-41    46+   0.4006 0.9451 -1.0757 1.8768  False
#  42-45    46+   0.6161 0.9501  -1.718 2.9503  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2637 0.0685 -0.5407 0.0134  False
#                    Female Non-binary / third gender  -0.1005 0.9858 -0.8549 0.6539  False
#                    Female         Prefer not to say   0.3404 0.8067 -0.6433 1.3242  False
#                      Male Non-binary / third gender   0.1632 0.9438 -0.5923 0.9186  False
#                      Male         Prefer not to say   0.6041 0.3869 -0.3804 1.5887  False
# Non-binary / third gender         Prefer not to say   0.4409 0.7807 -0.7681 1.6499  False
# -----------------------------------------------------------------------------------------
# PLAGIARISM ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    9.336535   12.0  1.032332  0.399839
# Residual                145.459624  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.2037 0.7023 -0.6408 0.2335  False
#  18-21  30-41  -0.2481 0.9802 -1.4605 0.9643  False
#  18-21  42-45   0.0348    1.0 -2.3676 2.4372  False
#  18-21    46+    0.025    1.0 -1.1875 1.2374  False
#  22-29  30-41  -0.0444    1.0 -1.3049 1.2161  False
#  22-29  42-45   0.2385 0.9988 -2.1886 2.6655  False
#  22-29    46+   0.2286 0.9874 -1.0319 1.4891  False
#  30-41  42-45   0.2829 0.9984 -2.3947 2.9605  False
#  30-41    46+    0.273 0.9919 -1.4204 1.9665  False
#  42-45    46+  -0.0099    1.0 -2.6874 2.6677  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0682  0.947 -0.2543 0.3908  False
#                    Female Non-binary / third gender   0.4194 0.6041 -0.4589 1.2977  False
#                    Female         Prefer not to say  -0.3261 0.8818 -1.4714 0.8192  False
#                      Male Non-binary / third gender   0.3511 0.7295 -0.5284 1.2307  False
#                      Male         Prefer not to say  -0.3943 0.8094 -1.5406 0.7519  False
# Non-binary / third gender         Prefer not to say  -0.7455 0.5184  -2.153 0.6621  False
# -----------------------------------------------------------------------------------------
# SOCIAL_IMPACT ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   18.651876   12.0  1.562358  0.172539
# Residual                192.007391  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.3829 0.2388  -0.893 0.1271  False
#  18-21  30-41  -0.9917  0.305 -2.4064 0.4229  False
#  18-21  42-45   0.8855 0.9077 -1.9177 3.6886  False
#  18-21    46+   0.4162 0.9274 -0.9985 1.8308  False
#  22-29  30-41  -0.6088 0.7853 -2.0796 0.8619  False
#  22-29  42-45   1.2684 0.7321 -1.5635 4.1002  False
#  22-29    46+   0.7991 0.5665 -0.6717 2.2698  False
#  30-41  42-45   1.8772 0.4649  -1.247 5.0014  False
#  30-41    46+   1.4079 0.2888  -0.568 3.3838  False
#  42-45    46+  -0.4693 0.9938 -3.5935 2.6549  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.0407 0.9924 -0.4185 0.3371  False
#                    Female Non-binary / third gender  -0.1056 0.9934 -1.1345 0.9232  False
#                    Female         Prefer not to say   1.4363 0.0306  0.0947  2.778   True
#                      Male Non-binary / third gender  -0.0649 0.9984 -1.0952 0.9653  False
#                      Male         Prefer not to say   1.4771 0.0247  0.1343 2.8198   True
# Non-binary / third gender         Prefer not to say    1.542 0.0761 -0.1068 3.1908  False
# -----------------------------------------------------------------------------------------
# HIGHERED_BENEFIT ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    1.838721   12.0  0.138008  0.983288
# Residual                214.282686  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0226    1.0 -0.5066 0.5518  False
#  18-21  30-41  -0.4987 0.8829 -1.9665 0.9691  False
#  18-21  42-45   0.2156 0.9996 -2.6929 3.1241  False
#  18-21    46+     0.93 0.4094 -0.5379 2.3978  False
#  22-29  30-41  -0.5213 0.8808 -2.0473 1.0048  False
#  22-29  42-45   0.1931 0.9998 -2.7453 3.1314  False
#  22-29    46+   0.9074 0.4757 -0.6187 2.4334  False
#  30-41  42-45   0.7143 0.9739 -2.5273  3.956  False
#  30-41    46+   1.4287  0.311 -0.6215 3.4788  False
#  42-45    46+   0.7143 0.9739 -2.5273  3.956  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2888 0.2197 -0.6768 0.0993  False
#                    Female Non-binary / third gender   -0.336 0.8431 -1.3927 0.7207  False
#                    Female         Prefer not to say   0.7865 0.4523 -0.5915 2.1644  False
#                      Male Non-binary / third gender  -0.0473 0.9994 -1.1054 1.0109  False
#                      Male         Prefer not to say   1.0752 0.1841 -0.3038 2.4543  False
# Non-binary / third gender         Prefer not to say   1.1225 0.3174  -0.571  2.816  False
# -----------------------------------------------------------------------------------------
# USAGE ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    6.475903   12.0  0.679539  0.639454
# Residual                153.271629  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0409 0.9993 -0.4301 0.5119  False
#  18-21  30-41   0.6254 0.6804 -0.6809 1.9318  False
#  18-21  42-45  -0.8659 0.8886 -3.4544 1.7226  False
#  18-21    46+   0.0876 0.9997 -1.2187 1.3939  False
#  22-29  30-41   0.5846 0.7601 -0.7736 1.9427  False
#  22-29  42-45  -0.9068 0.8749 -3.5218 1.7082  False
#  22-29    46+   0.0467    1.0 -1.3114 1.4049  False
#  30-41  42-45  -1.4914 0.6135 -4.3763 1.3936  False
#  30-41    46+  -0.5378 0.9269 -2.3625 1.2868  False
#  42-45    46+   0.9535 0.8929 -1.9314 3.8385  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.6648    0.0  -0.993 -0.3367   True
#                    Female Non-binary / third gender  -0.3935 0.6646 -1.2871     0.5  False
#                    Female         Prefer not to say  -0.6003  0.542 -1.7655  0.5649  False
#                      Male Non-binary / third gender   0.2713  0.861 -0.6235  1.1661  False
#                      Male         Prefer not to say   0.0645 0.9989 -1.1016  1.2307  False
# Non-binary / third gender         Prefer not to say  -0.2067 0.9821 -1.6388  1.2253  False
# ------------------------------------------------------------------------------------------
# RESP_USE_TRUST_BENEF ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    2.429877   12.0  0.337145  0.889982
# Residual                115.916229  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29    0.071 0.9884  -0.329  0.471  False
#  18-21  30-41   0.2682 0.9635 -0.8412 1.3777  False
#  18-21  42-45  -0.2647 0.9974 -2.4632 1.9337  False
#  18-21    46+   0.8269 0.2455 -0.2826 1.9364  False
#  22-29  30-41   0.1973 0.9899 -0.9562 1.3508  False
#  22-29  42-45  -0.3357 0.9937 -2.5567 1.8853  False
#  22-29    46+   0.7559 0.3741 -0.3976 1.9094  False
#  30-41  42-45   -0.533 0.9751 -2.9832 1.9173  False
#  30-41    46+   0.5587 0.8585  -0.991 2.1083  False
#  42-45    46+   1.0916  0.736 -1.3586 3.5419  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.4273 0.0008  -0.713 -0.1417   True
#                    Female Non-binary / third gender  -0.1297 0.9729 -0.9076  0.6482  False
#                    Female         Prefer not to say   0.5818 0.4479 -0.4326  1.5962  False
#                      Male Non-binary / third gender   0.2976 0.7554 -0.4814  1.0766  False
#                      Male         Prefer not to say   1.0091  0.052 -0.0061  2.0244  False
# Non-binary / third gender         Prefer not to say   0.7115 0.4524 -0.5352  1.9582  False
# ------------------------------------------------------------------------------------------
# TRUST ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq     df         F    PR(>F)
# C(AGE_RANGE)                   NaN    4.0       NaN       NaN
# C(GENDER)                      NaN    3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    6.814233   12.0  0.717801  0.610784
# Residual                152.682303  193.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0712 0.9923 -0.3761 0.5185  False
#  18-21  30-41   0.1645 0.9962 -1.0761 1.4052  False
#  18-21  42-45   1.0233 0.7818 -1.4351 3.4818  False
#  18-21    46+   1.3826 0.0205  0.1419 2.6233   True
#  22-29  30-41   0.0933 0.9996 -1.1966 1.3832  False
#  22-29  42-45   0.9521  0.829 -1.5315 3.4357  False
#  22-29    46+   1.3114 0.0442  0.0215 2.6013   True
#  30-41  42-45   0.8588 0.9101 -1.8812 3.5988  False
#  30-41    46+   1.2181 0.3023 -0.5148  2.951  False
#  42-45    46+   0.3593 0.9963 -2.3807 3.0993  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0389 0.9903 -0.2937 0.3715  False
#                    Female Non-binary / third gender  -0.1563 0.9701  -1.062 0.7494  False
#                    Female         Prefer not to say   1.2626  0.031  0.0815 2.4437   True
#                      Male Non-binary / third gender  -0.1952 0.9444 -1.1022 0.7118  False
#                      Male         Prefer not to say   1.2237 0.0393  0.0416 2.4058   True
# Non-binary / third gender         Prefer not to say   1.4189  0.058 -0.0327 2.8704  False
# -----------------------------------------------------------------------------------------

# %%
# (EL Code) 2-Way ANOVA for Instructors - Main Effects & Interactions 

# Define the list of variables
variables = ['AWARENESS', 'BENEFITS', 'LIMITATIONS', 'IMPLICATIONS',
             'WORK_PRODUCTIVITY', 'PLAGIARISM', 'SOCIAL_IMPACT',
             'HIGHERED_BENEFIT', 'USAGE', 'RESP_USE_TRUST_BENEF', 'TRUST']

# Define the factors
factors = ['AGE_RANGE', 'GENDER']

for target_name in variables:
    # Multi-way ANOVA
    formula = f"{target_name} ~ C(AGE_RANGE) * C(GENDER)"
    print(formula)

    # Perform the multi-way ANOVA
    model = sm.formula.ols(formula, data=instructors).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)

    print(f"Multi-way ANOVA Results:")
    print(anova_table)

    # Perform Tukey's HSD for pairwise comparisons for each factor
    for factor in factors:
        mc = MultiComparison(instructors[target_name], instructors[factor])
        result = mc.tukeyhsd()

        print(f"Tukey's HSD Results for {factor}:")
        print(result)
# Out:
# AWARENESS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                             sum_sq    df         F    PR(>F)
# C(AGE_RANGE)              0.538870   4.0  0.111944  0.738756
# C(GENDER)                      NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)    7.033432  12.0  0.487040  0.816361
# Residual                103.495206  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.1668 0.9999 -2.9475 3.2812  False
#  18-21  30-41  -0.2357 0.9995 -3.3014 2.8299  False
#  18-21  42-45  -0.6024 0.9841 -3.7658  2.561  False
#  18-21    46+  -0.2552 0.9993 -3.2855 2.7752  False
#  22-29  30-41  -0.4026 0.8185 -1.4439 0.6388  False
#  22-29  42-45  -0.7693  0.473 -2.0706 0.5321  False
#  22-29    46+   -0.422 0.7165 -1.3544 0.5104  False
#  30-41  42-45  -0.3667  0.909 -1.5467 0.8133  False
#  30-41    46+  -0.0194    1.0 -0.7732 0.7344  False
#  42-45    46+   0.3473 0.8997 -0.7377 1.4323  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2791 0.6034 -0.8682 0.3099  False
#                    Female Non-binary / third gender  -0.4418 0.9412 -2.4751 1.5915  False
#                    Female         Prefer not to say   0.1004 0.9997 -2.7493 2.9501  False
#                      Male Non-binary / third gender  -0.1627 0.9968 -2.2086 1.8833  False
#                      Male         Prefer not to say   0.3795 0.9855 -2.4792 3.2383  False
# Non-binary / third gender         Prefer not to say   0.5422 0.9766 -2.9161 4.0005  False
# -----------------------------------------------------------------------------------------
# BENEFITS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             3.398573   4.0  0.956886  0.330716
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)  18.203904  12.0  1.708468  0.128672
# Residual                76.361564  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.6421 0.9677 -2.1411 3.4253  False
#  18-21  30-41   0.9527  0.869 -1.7869 3.6923  False
#  18-21  42-45   0.8116 0.9303 -2.0155 3.6386  False
#  18-21    46+    1.248 0.7026 -1.4601 3.9561  False
#  22-29  30-41   0.3106 0.8851   -0.62 1.2412  False
#  22-29  42-45   0.1694 0.9942 -0.9935 1.3324  False
#  22-29    46+   0.6059 0.2632 -0.2274 1.4392  False
#  30-41  42-45  -0.1411 0.9958 -1.1956 0.9133  False
#  30-41    46+   0.2953 0.7398 -0.3783 0.9689  False
#  42-45    46+   0.4365 0.7206 -0.5332 1.4061  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   -0.428 0.1425 -0.9466 0.0906  False
#                    Female Non-binary / third gender  -1.2367 0.2764 -3.0266 0.5533  False
#                    Female         Prefer not to say   0.8502 0.8118 -1.6585 3.3589  False
#                      Male Non-binary / third gender  -0.8087 0.6443 -2.6098 0.9925  False
#                      Male         Prefer not to say   1.2782 0.5472 -1.2385 3.7949  False
# Non-binary / third gender         Prefer not to say   2.0869 0.2831 -0.9576 5.1313  False
# -----------------------------------------------------------------------------------------
# LIMITATIONS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             4.606893   4.0  1.210120  0.274378
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   8.161302  12.0  0.714593  0.638805
# Residual                81.849874  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.3276 0.9975 -2.4632 3.1184  False
#  18-21  30-41  -0.5555 0.9801 -3.3026 2.1916  False
#  18-21  42-45      0.0    1.0 -2.8347 2.8347  False
#  18-21    46+  -0.1253 0.9999 -2.8408 2.5902  False
#  22-29  30-41  -0.8831 0.0726 -1.8163   0.05  False
#  22-29  42-45  -0.3276 0.9353 -1.4937 0.8385  False
#  22-29    46+  -0.4529 0.5599 -1.2884 0.3827  False
#  30-41  42-45   0.5555 0.5896 -0.5019 1.6129  False
#  30-41    46+   0.4302 0.3958 -0.2452 1.1057  False
#  42-45    46+  -0.1253 0.9964 -1.0976  0.847  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2928 0.4781 -0.8249 0.2393  False
#                    Female Non-binary / third gender  -1.0647 0.4318 -2.9013 0.7718  False
#                    Female         Prefer not to say  -1.0647 0.7013 -3.6387 1.5093  False
#                      Male Non-binary / third gender  -0.7719 0.6948 -2.6199 1.0761  False
#                      Male         Prefer not to say  -0.7719 0.8624 -3.3541 1.8102  False
# Non-binary / third gender         Prefer not to say      0.0    1.0 -3.1237 3.1237  False
# -----------------------------------------------------------------------------------------
# IMPLICATIONS ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             0.050488   4.0  0.016057  0.899461
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   1.803538  12.0  0.191197  0.978537
# Residual                67.602447  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.8195 0.8904 -1.6723 3.3112  False
#  18-21  30-41   0.2316 0.9989 -2.2212 2.6844  False
#  18-21  42-45   0.4735 0.9851 -2.0576 3.0045  False
#  18-21    46+   0.3969  0.991 -2.0277 2.8214  False
#  22-29  30-41  -0.5879 0.2921  -1.421 0.2453  False
#  22-29  42-45   -0.346 0.8867 -1.3872 0.6952  False
#  22-29    46+  -0.4226 0.5163 -1.1686 0.3234  False
#  30-41  42-45   0.2419 0.9531 -0.7022  1.186  False
#  30-41    46+   0.1653 0.9406 -0.4378 0.7684  False
#  42-45    46+  -0.0766 0.9992 -0.9447 0.7915  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0118 0.9999 -0.4664 0.4901  False
#                    Female Non-binary / third gender   0.1184 0.9976 -1.5325 1.7692  False
#                    Female         Prefer not to say  -0.4143 0.9658  -2.728 1.8994  False
#                      Male Non-binary / third gender   0.1065 0.9983 -1.5546 1.7676  False
#                      Male         Prefer not to say  -0.4261 0.9633 -2.7472 1.8949  False
# Non-binary / third gender         Prefer not to say  -0.5326 0.9597 -3.3404 2.2752  False
# -----------------------------------------------------------------------------------------
# WORK_PRODUCTIVITY ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             0.758393   4.0  0.391056  0.533401
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)  18.204472  12.0  3.128974  0.008026
# Residual                41.695904  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.0528    1.0  -2.093 2.1985  False
#  18-21  30-41   0.3792 0.9872  -1.733 2.4913  False
#  18-21  42-45    0.453 0.9779 -1.7265 2.6326  False
#  18-21    46+   0.5356 0.9528 -1.5523 2.6234  False
#  22-29  30-41   0.3264 0.7126 -0.3911 1.0439  False
#  22-29  42-45   0.4003 0.7268 -0.4964 1.2969  False
#  22-29    46+   0.4828 0.2327 -0.1596 1.1252  False
#  30-41  42-45   0.0738 0.9991 -0.7391 0.8868  False
#  30-41    46+   0.1564  0.918 -0.3629 0.6757  False
#  42-45    46+   0.0826  0.998  -0.665 0.8301  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.3362 0.1256 -0.7326 0.0601  False
#                    Female Non-binary / third gender   0.3166 0.9301 -1.0515 1.6847  False
#                    Female         Prefer not to say   1.0533 0.4797 -0.8641 2.9708  False
#                      Male Non-binary / third gender   0.6528 0.6028 -0.7238 2.0295  False
#                      Male         Prefer not to say   1.3896 0.2394  -0.534 3.3131  False
# Non-binary / third gender         Prefer not to say   0.7367 0.8409 -1.5902 3.0637  False
# -----------------------------------------------------------------------------------------
# PLAGIARISM ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             2.618697   4.0  1.268323  0.263214
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   2.394748  12.0  0.386619  0.885747
# Residual                44.390904  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.2973 0.9941 -2.3301 1.7354  False
#  18-21  30-41  -0.7208 0.8536 -2.7217 1.2801  False
#  18-21  42-45  -0.6734 0.8934 -2.7381 1.3914  False
#  18-21    46+   -0.848 0.7553 -2.8259 1.1299  False
#  22-29  30-41  -0.4235 0.4187 -1.1032 0.2562  False
#  22-29  42-45   -0.376 0.7329 -1.2254 0.4734  False
#  22-29    46+  -0.5507 0.0955 -1.1593 0.0579  False
#  30-41  42-45   0.0475 0.9998 -0.7227 0.8176  False
#  30-41    46+  -0.1272 0.9515 -0.6192 0.3648  False
#  42-45    46+  -0.1747  0.959 -0.8829 0.5335  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0266  0.998 -0.3682 0.4214  False
#                    Female Non-binary / third gender   0.3136 0.9312 -1.0491 1.6762  False
#                    Female         Prefer not to say  -0.6414 0.8159 -2.5512 1.2684  False
#                      Male Non-binary / third gender    0.287  0.947 -1.0841 1.6581  False
#                      Male         Prefer not to say   -0.668 0.7984 -2.5838 1.2479  False
# Non-binary / third gender         Prefer not to say   -0.955 0.7038 -3.2726 1.3627  False
# -----------------------------------------------------------------------------------------
# SOCIAL_IMPACT ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             4.734525   4.0  1.278648  0.261294
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   7.306143  12.0  0.657721  0.683825
# Residual                79.609302  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.8664 0.9044 -3.6135 1.8807  False
#  18-21  30-41   -1.061 0.8103 -3.7651 1.6431  False
#  18-21  42-45  -1.2515 0.7233 -4.0418 1.5389  False
#  18-21    46+   -0.957 0.8564   -3.63  1.716  False
#  22-29  30-41  -0.1946 0.9763 -1.1132 0.7239  False
#  22-29  42-45  -0.3851 0.8832  -1.533 0.7628  False
#  22-29    46+  -0.0906  0.998 -0.9131 0.7319  False
#  30-41  42-45  -0.1904 0.9863 -1.2313 0.8504  False
#  30-41    46+    0.104 0.9924 -0.5609 0.7689  False
#  42-45    46+   0.2945  0.912 -0.6626 1.2516  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.0591 0.9908 -0.5782 0.4601  False
#                    Female Non-binary / third gender   0.0348    1.0 -1.7572 1.8268  False
#                    Female         Prefer not to say   0.9734 0.7417 -1.5382 3.4849  False
#                      Male Non-binary / third gender   0.0939 0.9991 -1.7093  1.897  False
#                      Male         Prefer not to say   1.0325 0.7073  -1.487  3.552  False
# Non-binary / third gender         Prefer not to say   0.9386 0.8516 -2.1093 3.9865  False
# -----------------------------------------------------------------------------------------
# HIGHERED_BENEFIT ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             1.786720   4.0  0.587043  0.445663
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   6.344836  12.0  0.694885  0.654360
# Residual                65.437231  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.6594 0.9476 -3.1531 1.8343  False
#  18-21  30-41  -0.6212 0.9551 -3.0758 1.8335  False
#  18-21  42-45  -0.3175 0.9968 -2.8505 2.2155  False
#  18-21    46+  -0.3362 0.9952 -2.7626 2.0903  False
#  22-29  30-41   0.0382 0.9999 -0.7956  0.872  False
#  22-29  42-45   0.3419 0.8912 -0.7001 1.3839  False
#  22-29    46+   0.3232 0.7487 -0.4234 1.0698  False
#  30-41  42-45   0.3037 0.8983 -0.6411 1.2485  False
#  30-41    46+    0.285 0.6833 -0.3186 0.8886  False
#  42-45    46+  -0.0187    1.0 -0.8875 0.8501  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.2897 0.3742 -0.7584  0.179  False
#                    Female Non-binary / third gender  -0.3968 0.9182 -2.0147  1.221  False
#                    Female         Prefer not to say   0.3175 0.9831   -1.95  2.585  False
#                      Male Non-binary / third gender  -0.1071 0.9982 -1.7351 1.5208  False
#                      Male         Prefer not to say   0.6072 0.8975 -1.6675 2.8819  False
# Non-binary / third gender         Prefer not to say   0.7143 0.9048 -2.0374 3.4661  False
# -----------------------------------------------------------------------------------------
# USAGE ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             5.505965   4.0  2.652953  0.107016
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)  31.846312  12.0  5.114864  0.000156
# Residual                44.621304  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29  -0.6562 0.9359 -2.9987 1.6864  False
#  18-21  30-41  -0.9625 0.7731 -3.2684 1.3433  False
#  18-21  42-45  -0.7435 0.9073 -3.1229  1.636  False
#  18-21    46+  -0.5469 0.9628 -2.8262 1.7325  False
#  22-29  30-41  -0.3064 0.8121 -1.0896 0.4769  False
#  22-29  42-45  -0.0873 0.9991 -1.0661 0.8916  False
#  22-29    46+   0.1093 0.9925  -0.592 0.8107  False
#  30-41  42-45   0.2191 0.9589 -0.6685 1.1066  False
#  30-41    46+   0.4157 0.2554 -0.1513 0.9827  False
#  42-45    46+   0.1966 0.9623 -0.6195 1.0128  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================================================
#           group1                    group2          meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------------------------
#                    Female                      Male  -0.6695 0.0002 -1.0761 -0.2629   True
#                    Female Non-binary / third gender   0.3917 0.8848 -1.0119  1.7953  False
#                    Female         Prefer not to say  -1.2557 0.3454 -3.2229  0.7115  False
#                      Male Non-binary / third gender   1.0612 0.2085 -0.3511  2.4736  False
#                      Male         Prefer not to say  -0.5862 0.8646 -2.5596  1.3872  False
# Non-binary / third gender         Prefer not to say  -1.6474 0.2774 -4.0347  0.7399  False
# ------------------------------------------------------------------------------------------
# RESP_USE_TRUST_BENEF ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             0.009686   4.0  0.005882  0.939045
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)  13.812198  12.0  2.795841  0.015620
# Residual                35.405239  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.1137 0.9998 -1.8446  2.072  False
#  18-21  30-41   0.1099 0.9999 -1.8177 2.0376  False
#  18-21  42-45   0.2872 0.9944  -1.702 2.2763  False
#  18-21    46+   0.5228 0.9404 -1.3827 2.4283  False
#  22-29  30-41  -0.0037    1.0 -0.6585 0.6511  False
#  22-29  42-45   0.1735 0.9763 -0.6448 0.9918  False
#  22-29    46+   0.4091  0.303 -0.1772 0.9954  False
#  30-41  42-45   0.1772 0.9634 -0.5647 0.9192  False
#  30-41    46+   0.4129 0.1182 -0.0611 0.8868  False
#  42-45    46+   0.2356 0.8718 -0.4467 0.9179  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male  -0.3495 0.0722 -0.7204 0.0214  False
#                    Female Non-binary / third gender  -0.2592 0.9517 -1.5393 1.0209  False
#                    Female         Prefer not to say   0.3654 0.9509 -1.4287 2.1595  False
#                      Male Non-binary / third gender   0.0903 0.9978 -1.1978 1.3784  False
#                      Male         Prefer not to say   0.7149  0.727 -1.0849 2.5147  False
# Non-binary / third gender         Prefer not to say   0.6246 0.8762 -1.5527 2.8018  False
# -----------------------------------------------------------------------------------------
# TRUST ~ C(AGE_RANGE) * C(GENDER)
# Multi-way ANOVA Results:
#                            sum_sq    df         F    PR(>F)
# C(AGE_RANGE)             2.783072   4.0  0.899408  0.345598
# C(GENDER)                     NaN   3.0       NaN       NaN
# C(AGE_RANGE):C(GENDER)   5.517656  12.0  0.594382  0.734006
# Residual                66.528273  86.0       NaN       NaN
# Tukey's HSD Results for AGE_RANGE:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#  18-21  22-29   0.2259 0.9991 -2.2801 2.7318  False
#  18-21  30-41   0.6545 0.9469 -1.8122 3.1213  False
#  18-21  42-45   0.5344 0.9771  -2.011 3.0799  False
#  18-21    46+   0.5451 0.9712 -1.8933 2.9834  False
#  22-29  30-41   0.4287 0.6142 -0.4092 1.2666  False
#  22-29  42-45   0.3086 0.9238 -0.7386 1.3557  False
#  22-29    46+   0.3192 0.7606 -0.4311 1.0695  False
#  30-41  42-45  -0.1201 0.9967 -1.0696 0.8293  False
#  30-41    46+  -0.1095  0.987  -0.716  0.497  False
#  42-45    46+   0.0106    1.0 -0.8624 0.8837  False
# ---------------------------------------------------
# Tukey's HSD Results for GENDER:
#                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================
#           group1                    group2          meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------------------
#                    Female                      Male   0.0856 0.9638 -0.3829 0.5541  False
#                    Female Non-binary / third gender  -0.0972 0.9986 -1.7144 1.5199  False
#                    Female         Prefer not to say   1.5895 0.2638  -0.677 3.8559  False
#                      Male Non-binary / third gender  -0.1828 0.9911   -1.81 1.4444  False
#                      Male         Prefer not to say   1.5039 0.3139 -0.7698 3.7776  False
# Non-binary / third gender         Prefer not to say   1.6867 0.3813 -1.0638 4.4372  False
# -----------------------------------------------------------------------------------------
